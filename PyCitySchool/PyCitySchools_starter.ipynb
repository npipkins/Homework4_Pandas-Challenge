# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
student_data
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0                 66          79
# 1                 94          61
# ...

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
#DataFrame
district_summary = pd.DataFrame()
#Total Number of Schools
district_summary['Total Schools'] = [len(school_data_complete['school_name'].unique())]
#Total Number of Students
Total_Students = len(school_data_complete['Student ID'].unique())
district_summary['Total Students'] = [Total_Students]
#Total Budget
district_summary['Total Budget'] = [sum(school_data_complete['budget'].unique())]
#Average Math Score
district_summary['Average Math Score'] = [(school_data_complete['math_score'].mean())]
#Average Reading Score
district_summary['Average Reading Score'] = [(school_data_complete['reading_score'].mean())]
#Percetnage of Students Passing Math
district_summary['% Passing Math'] = [((len(school_data_complete[school_data_complete['math_score'] >= 70])/Total_Students)*100.0)]
#Percetnage of Students Passing Reading
district_summary['% Passing Reading'] = [((len(school_data_complete[school_data_complete['reading_score'] >= 70])/Total_Students)*100.0)]
#Percetnage of Students Passing Overall
district_summary['% Overall Passing'] = [((len(school_data_complete[(school_data_complete['math_score'] >= 70) 
                                                                             & (school_data_complete['reading_score'] >= 70)])/Total_Students)*100.0)]
#Formatting the Data
district_summary.style.format({'Total Schools': "{:}",
                 'Total Students': "{:,.0f}",
                 'Total Budget': "${:,.2f}", 
                 'Average Math Score': "{:.6f}",
                 'Average Reading Score': "{:.6f}",
                 '% Passing Math': "{:.6f}",
                 '% Passing Reading': "{:.6f}",
                 '% Overall Passing': "{:.6f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_4502c36e_ebef_11ea_9ebc_ac87a30fe5e0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Schools</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total Budget</th>        <th class="col_heading level0 col3" >Average Math Score</th>        <th class="col_heading level0 col4" >Average Reading Score</th>        <th class="col_heading level0 col5" >% Passing Math</th>        <th class="col_heading level0 col6" >% Passing Reading</th>        <th class="col_heading level0 col7" >% Overall Passing</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4502c36e_ebef_11ea_9ebc_ac87a30fe5e0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4502c36e_ebef_11ea_9ebc_ac87a30fe5e0row0_col0" class="data row0 col0" >15</td>
# ...

# %%
# school = school_data.set_index('school_name')

# school_type = school_data.groupby('school_name')['type'].unique()

# total_students_per_school = school_data.groupby('school_name')['size'].unique()

# budget_per_school = school_data.groupby('school_name')['budget'].unique()

# budget_per_student = budget_per_school/total_students_per_school

# student_data.groupby('school_name')['math_score'].mean()

# student_data.groupby('school_name')['reading_score'].mean()

# student_data[student_data['math_score'] >= 70]
# passing_score_math.groupby('school_name')['math_score'].count()
# avg_passing_math_per_school = passingmath_score_per_school/total_students_per_school

# student_data[student_data['reading_score'] >= 70]
# passing_score_reading.groupby('school_name')['reading_score'].count()
# avg_passing_reading_per_school = passingenglish_score_per_school/total_students_per_school

# perc_passing_math = passingmath_score_per_school/total_students_per_school
# perc_passing_reading = passingenglish_score_per_school/total_students_per_school

# passing_score_overall = student_data[(student_data['math_score'] >= 70) 
#                                                   & (student_data['reading_score'] >= 70)]
# overall_score_per_school = passing_score_overall.groupby('school_name')['reading_score'].count()
# passing_overall_per_school = overall_score_per_school/total_students_per_school

# %%
# school = school_data_complete.set_index('school_name').groupby(['school_name'])
# types = school_data.set_index('school_name')['type']
# student_school = school_data_complete.groupby("school_name")['Student ID'].count()
# student_school = school_data.set_index('school_name')['size']
# school_budget = school_data.groupby('school_name')['budget']
# student_budget = school_data.set_index('school_name')['budget']

# school_summary = pd.DataFrame({
#     "School Type": types,
#     "Total Students": student_school,
#     "Per Student Budget": student_budget})

# school_summary = school_summary[['School Type', 
#                           'Total Students', 
#                           'Per Student Budget']]

# school_summary = school_summary.style.format({'Total Students': '{:,}', 
#                           "Per Student Budget": "${:,}"})

# school_summary

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
# school = school_data.set_index('school_name')['school_name'].value

# school_type = school_data.groupby('school_name')['type']

school = school_data_complete.set_index('school_name').groupby(['school_name'])

types = school_data.set_index('school_name')['type']

total_students_per_school = school_data_complete.groupby('school_name')['size'].count()

budget_per_school = school_data_complete.groupby('school_name')['budget'].mean()

budget_per_student = budget_per_school/total_students_per_school

avg_math_score_per_school = student_data.groupby('school_name')['math_score'].mean()

avg_reading_score_per_school = student_data.groupby('school_name')['reading_score'].mean()

passing_score_math = student_data[student_data['math_score'] >= 70]
passingmath_score_per_school = passing_score_math.groupby('school_name')['math_score'].count()
avg_passing_math_per_school = ((passingmath_score_per_school/total_students_per_school)*100)

passing_score_reading = student_data[student_data['reading_score'] >= 70]
passingenglish_score_per_school = passing_score_reading.groupby('school_name')['reading_score'].count()
avg_passing_reading_per_school = ((passingenglish_score_per_school/total_students_per_school)*100)

perc_passing_math = ((passingmath_score_per_school/total_students_per_school)*100)
perc_passing_reading = ((passingenglish_score_per_school/total_students_per_school)*100)

passing_score_overall = student_data[(student_data['math_score'] >= 70) 
                                                  & (student_data['reading_score'] >= 70)]
overall_score_per_school = passing_score_overall.groupby('school_name')['reading_score'].count()
passing_overall_per_school = ((overall_score_per_school/total_students_per_school)*100)


school_summary = pd.DataFrame({
    "School Type": types,
    "Total Students": total_students_per_school,
    "Total School Budget": budget_per_school,
    "Per Student Budget": budget_per_student,
    "Average Math Score": avg_passing_math_per_school,
    "Average Reading Score": avg_passing_reading_per_school,
    '% Passing Math': perc_passing_math,
    '% Passing Reading': perc_passing_reading,
    "% Overall Passing": passing_overall_per_school})

school_summary = school_summary[['School Type',
                                'Total Students',
                                'Total School Budget',
                                'Per Student Budget',
                                'Average Math Score',
                                'Average Reading Score',
                                '% Passing Math',
                                '% Passing Reading',
                                '% Overall Passing']]

y = school_summary.style.format({'Total Students': '{:,}',
                            "Total School Budget": "${:,}",
                            "Per Student Budget": "${:.2f}",
                            'Average Math Score': "{:.6f}",
                            'Average Reading Score': "{:.6f}",
                            "% Passing Math": "{:.6f}%",
                            "% Passing Reading": "{:.6f}%",
                            "% Overall Passing": "{:.6f}%"})

y
# Out:
# <style  type="text/css" >
# </style><table id="T_43ca7d50_ebf1_11ea_9ebc_ac87a30fe5e0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >School Type</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total School Budget</th>        <th class="col_heading level0 col3" >Per Student Budget</th>        <th class="col_heading level0 col4" >Average Math Score</th>        <th class="col_heading level0 col5" >Average Reading Score</th>        <th class="col_heading level0 col6" >% Passing Math</th>        <th class="col_heading level0 col7" >% Passing Reading</th>        <th class="col_heading level0 col8" >% Overall Passing</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_43ca7d50_ebf1_11ea_9ebc_ac87a30fe5e0level0_row0" class="row_heading level0 row0" >Bailey High School</th>
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
top_performing_schools=school_summary.sort_values("% Overall Passing", ascending = False)
top_performing_schools.head(5)
# Out:
#                     School Type  Total Students  Total School Budget  \
# Cabrera High School     Charter            1858              1081356
# Thomas High School      Charter            1635              1043130
# Griffin High School     Charter            1468               917500
# Wilson High School      Charter            2283              1319574
# Pena High School        Charter             962               585858
#
#                      Per Student Budget  Average Math Score  \
# Cabrera High School               582.0           94.133477
# Thomas High School                638.0           93.272171
# Griffin High School               625.0           93.392371
# Wilson High School                578.0           93.867718
# Pena High School                  609.0           94.594595
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              97.039828       94.133477          97.039828
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
bottom_performing_schools=school_summary.sort_values("% Overall Passing", ascending = True)
bottom_performing_schools.head(5)
# Out:
#                       School Type  Total Students  Total School Budget  \
# Rodriguez High School    District            3999              2547363
# Figueroa High School     District            2949              1884411
# Huang High School        District            2917              1910635
# Hernandez High School    District            4635              3022020
# Johnson High School      District            4761              3094650
#
#                        Per Student Budget  Average Math Score  \
# Rodriguez High School               637.0           66.366592
# Figueroa High School                639.0           65.988471
# Huang High School                   655.0           65.683922
# Hernandez High School               652.0           66.752967
# Johnson High School                 650.0           66.057551
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.220055       66.366592
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
math_scores_by_grade = student_data.groupby (["school_name", "grade"])["math_score"].mean()
math_scores_by_grade
# Out:
# school_name            grade
# Bailey High School     10th     76.996772
#                        11th     77.515588
#                        12th     76.492218
#                        9th      77.083676
# Cabrera High School    10th     83.154506
#                        11th     82.765560
#                        12th     83.277487
#                        9th      83.094697
# Figueroa High School   10th     76.539974
#                        11th     76.884344
#                        12th     77.151369
#                        9th      76.403037
# Ford High School       10th     77.672316
#                        11th     76.918058
#                        12th     76.179963
#                        9th      77.361345
# Griffin High School    10th     84.229064
#                        11th     83.842105
#                        12th     83.356164
#                        9th      82.044010
# Hernandez High School  10th     77.337408
#                        11th     77.136029
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
math_scores_by_grade = student_data.groupby (["school_name", "grade"])["reading_score"].mean()
math_scores_by_grade
# Out:
# school_name            grade
# Bailey High School     10th     80.907183
#                        11th     80.945643
#                        12th     80.912451
#                        9th      81.303155
# Cabrera High School    10th     84.253219
#                        11th     83.788382
#                        12th     84.287958
#                        9th      83.676136
# Figueroa High School   10th     81.408912
#                        11th     80.640339
#                        12th     81.384863
#                        9th      81.198598
# Ford High School       10th     81.262712
#                        11th     80.403642
#                        12th     80.662338
#                        9th      80.632653
# Griffin High School    10th     83.706897
#                        11th     84.288089
#                        12th     84.013699
#                        9th      83.369193
# Hernandez High School  10th     80.660147
#                        11th     81.396140
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              96.586489          90.432244
# District             80.799062          53.672208
